# %%
from tc import config

# %%
import tc.config as config

# %%
#main.py file

import pandas as pd
import copy
import tc.config as config
from tc.data_import import ImportData
from tc.distance_calc import DistanceCalculation
from tc.results_page import ResultCalculations ,calculate_lift

# %%
config.numerical_columns
# Out:
# ['NRx',
#  'PDE',
#  'Copay',
#  'Delivered_Doximity',
#  'Delivered_Epocrates',
#  'Engaged_Doximity',
#  'Engaged_Epocrates',
#  'Delivered_Medscape',
#  'Engaged_Medscape',
#  'Delivered_Nexgen',
#  'Engaged_Nexgen',
#  'SpeakerEvent']

# %%
#Import Page module

dataset_import = ImportData(
    file_path="MMX_Data_PDE_Reduced.csv",
    data_format="long",
    date_format="yyyy-mm",
    date_col=config.date_columns,
    categorical_cols=config.categorical_columns,
    numerical_cols=config.numerical_columns,
    identifier=config.hcp_identifier,
    week=False

)

# %%
config.numerical_columns
# Out:
# ['NRx',
#  'PDE',
#  'Copay',
#  'Delivered_Doximity',
#  'Delivered_Epocrates',
#  'Engaged_Doximity',
#  'Engaged_Epocrates',
#  'Delivered_Medscape',
#  'Engaged_Medscape',
#  'Delivered_Nexgen',
#  'Engaged_Nexgen',
#  'SpeakerEvent']

# %%
read_data = dataset_import.read_csv()
# Out:
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\data_import.py:77: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_df = data.pivot_table(

# %%
read_data.head()
# Out:
#       ID  Copay_Jul19  Copay_Aug19  Copay_Sep19  Copay_Oct19  Copay_Nov19  \
# 0  14934          4.0          5.0          4.0          2.0          3.0
# 1  14935          5.0          2.0          2.0          1.0          4.0
# 2  14936          3.0          1.0          1.0          3.0          5.0
# 3  14937          4.0          3.0          1.0          2.0          2.0
# 4  14938          2.0          3.0          3.0          1.0          2.0
#
#    Copay_Dec19  Copay_Jan20  Copay_Feb20  Copay_Mar20  ...  TV_GRPs  \
# 0          4.0          5.0          4.0          3.0  ...      279
# 1          4.0          1.0          2.0          4.0  ...      918
# 2          4.0          2.0          5.0          3.0  ...      157
# 3          2.0          4.0          5.0          3.0  ...      425
# 4          4.0          2.0          4.0          1.0  ...      921
#
#    Display_Impressions  Display_Clicks  Print_GRPs  TV2_GRPs  \
# 0                  377              80         973       438
# 1                  506             723         886       777
# 2                   94             998         354       306
# 3                  416             978         565       268
# 4                  447             242         672       713
#
#    Display2_Impressions  Display2_Clicks  Print2_GRPs  TC  Date1
# 0                   622              347          729   C  Jul19
# 1                   943              621          495   C  Jul19
# 2                   650              219          559   C  Jul19
# 3                   375              265          242   T  Jul19
# 4                   276              734          740   C  Jul19
#
# [5 rows x 173 columns]

# %%
event_identifer = 'SpeakerEvent'

# %%
# Distance Calculation Module


dist_calc=DistanceCalculation(
data=read_data,
num_cols=config.numerical_columns,
hcp_identifier=config.hcp_identifier,
tc_identifier=config.tc_identifier,
event_identifier=config.event_identifer)

# %%
time_aligned_data=dist_calc.time_align(test_filter_value=config.test_value,post_cut_off=0)
# Out:
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\distance_calc.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   time_align['Post_Start'] = time_align['Post_Start'].replace(mapping_dict)

# %%
data_conversion=dist_calc.column_conversion()

# %%
original_data_conversion = copy.deepcopy(data_conversion)
dist_calc.data_standardize()
# Out:
#          ID       Zip       NRx       TRx    MktNRx    MktTRx       PDE  \
# 0     14934  0.023339 -0.507894 -0.436143 -0.517040 -0.519036 -0.494052
# 1     14935 -0.718087 -0.507894 -0.344695 -0.517040 -0.519036 -0.300096
# 2     14936  1.458982 -0.344974 -0.436143 -0.584805 -0.574681 -0.397074
# 3     14937  1.325510 -0.344974 -0.344695 -0.449275 -0.463391 -0.755893
# 4     14938 -0.635234 -0.833735 -0.253247 -0.381510 -0.240812 -1.143805
# ...     ...       ...       ...       ...       ...       ...       ...
# 4048  18982  1.573121 -0.996655 -0.436143 -0.245980 -0.296457 -0.969245
# 4049  18983  0.638394 -0.344974 -0.436143 -0.584805 -0.574681  0.970316
# 4050  18984 -0.700687  0.306706 -0.161799 -0.381510 -0.296457 -0.697706
# 4051  18985 -1.210320 -1.159575 -0.436143 -0.517040 -0.407747 -1.201992
# 4052  18986 -0.848430  1.772988 -0.253247 -0.313745 -0.352102  1.047899
#
#          Copay  Delivered_Doximity  Delivered_Epocrates  ...  \
# 0     0.667972           -1.471731            -1.792143  ...
# 1     1.368616           -0.513741             0.410269  ...
# 2    -0.032673            0.444249            -0.690937  ...
# 3     0.667972           -0.513741             0.410269  ...
# 4    -0.733317           -0.513741             0.410269  ...
# ...        ...                 ...                  ...  ...
# 4048  1.368616           -0.992736            -1.792143  ...
# 4049  0.667972           -0.513741            -0.690937  ...
# 4050 -0.032673            0.923244             0.410269  ...
# 4051 -1.433961           -0.992736            -1.792143  ...
# 4052 -1.433961            2.360230             1.511475  ...
#
#       Engaged_Nexgen_5  Engaged_Nexgen_6  Engaged_Nexgen_7  Engaged_Nexgen_8  \
# 0            -0.004210               NaN               NaN         -1.209360
# 1            -1.222965               NaN               NaN         -1.209360
# 2             1.214545               NaN               NaN          1.261795
# 3            -1.222965               NaN               NaN          1.261795
# 4             1.214545               NaN               NaN         -1.209360
# ...                ...               ...               ...               ...
# 4048          1.214545               NaN               NaN         -1.209360
# 4049         -0.004210               NaN               NaN         -1.209360
# 4050         -1.222965               NaN               NaN          0.026218
# 4051          1.214545               NaN               NaN          0.026218
# 4052         -1.222965               NaN               NaN         -1.209360
#
#       Engaged_Nexgen_9  Engaged_Nexgen_10  Engaged_Nexgen_11  \
# 0            -1.204534                NaN                NaN
# 1             0.021477                NaN                NaN
# 2            -1.204534                NaN                NaN
# 3            -1.204534                NaN                NaN
# 4             1.247488                NaN                NaN
# ...                ...                ...                ...
# 4048         -1.204534                NaN                NaN
# 4049          1.247488                NaN                NaN
# 4050          0.021477                NaN                NaN
# 4051         -1.204534                NaN                NaN
# 4052          0.021477                NaN                NaN
#
#      Engaged_Nexgen_12  Engaged_Nexgen_13  SpeakerEvent_1
# 0                  NaN                NaN        1.263651
# 1                  NaN                NaN        0.012044
# 2                  NaN                NaN        1.263651
# 3                  NaN                NaN       -1.239563
# 4                  NaN                NaN       -1.239563
# ...                ...                ...             ...
# 4048               NaN                NaN        0.012044
# 4049               NaN                NaN        0.012044
# 4050               NaN                NaN        1.263651
# 4051               NaN                NaN       -1.239563
# 4052               NaN                NaN       -1.239563
#
# [4053 rows x 173 columns]

# %%
result=dist_calc.distance_matching(
control_matches=1,
agg_matching=True,
segment_matching=False,
filter_test_val=config.test_value,
filter_control_val=config.control_value,
segment_var=config.segment_var,
batch_size=config.batch_size
)
# Out:
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\distance_calc.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.data['segment_var']="National"
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\distance_calc.py:187: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result_df = pd.concat([result_df, col_result_df], ignore_index=True)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6', 'NRx_7']
# ['NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6', 'NRx_7']
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# ['NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6', 'NRx_7']
# ['NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6', 'NRx_7']
# ['NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6', 'NRx_7']
# ['NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6', 'NRx_7']
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows

# %%
# # #Result Page Module

result_calc=ResultCalculations(
    matching_data=result,
    time_aligned_data=time_aligned_data,
    data_conversion=original_data_conversion,
    hcp_identifier=config.hcp_identifier
)

# %%
result_calc.data_merge()
avgs_data=result_calc.avgs_calculation()
graph_data_test,graph_data_control=result_calc.graph_data_generation()

avgs_table,lift=calculate_lift(avgs_data,config.sales_var)
# Out:
# NRx
# 0
# ['NRx_1', 'NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6']
# ['NRx_7', 'NRx_8', 'NRx_9', 'NRx_10', 'NRx_11', 'NRx_12']
# NRx
# 1
# ['NRx_2', 'NRx_3', 'NRx_4', 'NRx_5', 'NRx_6', 'NRx_7']
# ['NRx_8', 'NRx_9', 'NRx_10', 'NRx_11', 'NRx_12', 'NRx_13']
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)

# %%
lift
# Out:
# 0.14128843751943848

# %%
#Import Page module

dataset_import = ImportData(
    file_path="TC_Data_Wide.csv",
    data_format="wide",
    date_format="yyyy-mm",
    date_col=config.date_columns,
    categorical_cols=config.categorical_columns,
    numerical_cols=config.numerical_columns,
    identifier=config.hcp_identifier,
    week=False

)
read_data = dataset_import.read_csv()


# Distance Calculation Module

event_identifers = ['Speaker_Program','Mobile_Alerts']


res = {}
avg_table_dict = {}

for event_identifier in event_identifers:
    dist_calc=DistanceCalculation(
    data=read_data,
    num_cols=config.numerical_columns,
    hcp_identifier=config.hcp_identifier,
    tc_identifier=config.tc_identifier,
    event_identifier=event_identifier)

    time_aligned_data=dist_calc.time_align(test_filter_value=config.test_value,post_cut_off=0)

    data_conversion=dist_calc.column_conversion()

    original_data_conversion = copy.deepcopy(data_conversion)
    dist_calc.data_standardize()

    result=dist_calc.distance_matching(
    control_matches=1,
    agg_matching=True,
    segment_matching=False,
    filter_test_val=config.test_value,
    filter_control_val=config.control_value,
    segment_var=config.segment_var,
    batch_size=config.batch_size
    )




    # # #Result Page Module

    result_calc=ResultCalculations(
        matching_data=result,
        time_aligned_data=time_aligned_data,
        data_conversion=original_data_conversion,
        hcp_identifier=config.hcp_identifier
    )
    result_calc.data_merge()
    avgs_data=result_calc.avgs_calculation()
    graph_data_test,graph_data_control=result_calc.graph_data_generation()

    avgs_table,lift=calculate_lift(avgs_data,config.sales_var)

    # add lift of event_identifier to result dictionary
    res[event_identifier]=lift
    avg_table_dict[event_identifier]=avgs_table
# Out:
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\distance_calc.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   time_align['Post_Start'] = time_align['Post_Start'].replace(mapping_dict)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\distance_calc.py:184: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result_df = pd.concat([result_df, col_result_df], ignore_index=True)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# ['Emails_3', 'Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10']
# ['Calls_3', 'Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10']
# ['Brand_Sales_3', 'Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10']
# ['Emails_3', 'Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10']
# ['Calls_3', 'Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10']
# ['Brand_Sales_3', 'Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10']
# ['Emails_3', 'Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10']
# ['Calls_3', 'Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10']
# ['Brand_Sales_3', 'Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10']
# ['Emails_3', 'Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10']
# ['Calls_3', 'Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10']
# ['Brand_Sales_3', 'Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10']
# ['Emails_3', 'Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10']
# ['Calls_3', 'Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10']
# ['Brand_Sales_3', 'Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10']
# ['Emails_3', 'Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10']
# ['Calls_3', 'Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10']
# ['Brand_Sales_3', 'Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10']
# ['Emails_3', 'Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10']
# ['Calls_3', 'Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10']
# ['Brand_Sales_3', 'Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10']
# ['Emails_3', 'Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10']
# ['Calls_3', 'Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10']
# ['Brand_Sales_3', 'Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10']
# ['Emails_3', 'Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10']
# ['Calls_3', 'Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10']
# ['Brand_Sales_3', 'Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10']
# ['Emails_3', 'Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10']
# ['Calls_3', 'Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10']
# ['Brand_Sales_3', 'Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10']
# ['Emails_3', 'Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10']
# ['Calls_3', 'Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10']
# ['Brand_Sales_3', 'Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10']
# ['Emails_3', 'Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10']
# ['Calls_3', 'Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10']
# ['Brand_Sales_3', 'Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10']
# ['Emails_3', 'Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10']
# ['Calls_3', 'Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10']
# ['Brand_Sales_3', 'Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10']
# ['Emails_3', 'Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10']
# ['Calls_3', 'Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10']
# ['Brand_Sales_3', 'Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10']
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# ['Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10', 'Emails_11']
# ['Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10', 'Calls_11']
# ['Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10', 'Brand_Sales_11']
# ['Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10', 'Emails_11']
# ['Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10', 'Calls_11']
# ['Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10', 'Brand_Sales_11']
# ['Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10', 'Emails_11']
# ['Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10', 'Calls_11']
# ['Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10', 'Brand_Sales_11']
# ['Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10', 'Emails_11']
# ['Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10', 'Calls_11']
# ['Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10', 'Brand_Sales_11']
# ['Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10', 'Emails_11', 'Emails_12']
# ['Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10', 'Calls_11', 'Calls_12']
# ['Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10', 'Brand_Sales_11', 'Brand_Sales_12']
# ['Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10', 'Emails_11', 'Emails_12']
# ['Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10', 'Calls_11', 'Calls_12']
# ['Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10', 'Brand_Sales_11', 'Brand_Sales_12']
# ['Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10', 'Emails_11', 'Emails_12', 'Emails_13']
# ['Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10', 'Calls_11', 'Calls_12', 'Calls_13']
# ['Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10', 'Brand_Sales_11', 'Brand_Sales_12', 'Brand_Sales_13']
# ['Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10', 'Emails_11', 'Emails_12', 'Emails_13']
# ['Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10', 'Calls_11', 'Calls_12', 'Calls_13']
# ['Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10', 'Brand_Sales_11', 'Brand_Sales_12', 'Brand_Sales_13']
# ['Emails_7', 'Emails_8', 'Emails_9', 'Emails_10', 'Emails_11', 'Emails_12', 'Emails_13', 'Emails_14']
# ['Calls_7', 'Calls_8', 'Calls_9', 'Calls_10', 'Calls_11', 'Calls_12', 'Calls_13', 'Calls_14']
# ['Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10', 'Brand_Sales_11', 'Brand_Sales_12', 'Brand_Sales_13', 'Brand_Sales_14']
# ['Emails_7', 'Emails_8', 'Emails_9', 'Emails_10', 'Emails_11', 'Emails_12', 'Emails_13', 'Emails_14']
# ['Calls_7', 'Calls_8', 'Calls_9', 'Calls_10', 'Calls_11', 'Calls_12', 'Calls_13', 'Calls_14']
# ['Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10', 'Brand_Sales_11', 'Brand_Sales_12', 'Brand_Sales_13', 'Brand_Sales_14']
# Emails
# 0
# ['Emails_3', 'Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10']
# ['Emails_11', 'Emails_12']
# Calls
# 0
# ['Calls_3', 'Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10']
# ['Calls_11', 'Calls_12']
# Brand_Sales
# 0
# ['Brand_Sales_3', 'Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10']
# ['Brand_Sales_11', 'Brand_Sales_12']
# Emails
# 1
# ['Emails_4', 'Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10', 'Emails_11']
# ['Emails_12', 'Emails_13']
# Calls
# 1
# ['Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10', 'Calls_11']
# ['Calls_12', 'Calls_13']
# Brand_Sales
# 1
# ['Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10', 'Brand_Sales_11']
# ['Brand_Sales_12', 'Brand_Sales_13']
# Emails
# 2
# ['Emails_5', 'Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10', 'Emails_11', 'Emails_12']
# ['Emails_13', 'Emails_14']
# Calls
# 2
# ['Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10', 'Calls_11', 'Calls_12']
# ['Calls_13', 'Calls_14']
# Brand_Sales
# 2
# ['Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10', 'Brand_Sales_11', 'Brand_Sales_12']
# ['Brand_Sales_13', 'Brand_Sales_14']
# Emails
# 3
# ['Emails_6', 'Emails_7', 'Emails_8', 'Emails_9', 'Emails_10', 'Emails_11', 'Emails_12', 'Emails_13']
# ['Emails_14', 'Emails_15']
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\agg_logic.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[relevant_columns].sum(axis=1)  # Calculate sum along rows
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)
# Calls
# 1
# ['Calls_4', 'Calls_5', 'Calls_6', 'Calls_7', 'Calls_8', 'Calls_9', 'Calls_10', 'Calls_11']
# ['Calls_12', 'Calls_13']
# Brand_Sales
# 1
# ['Brand_Sales_4', 'Brand_Sales_5', 'Brand_Sales_6', 'Brand_Sales_7', 'Brand_Sales_8', 'Brand_Sales_9', 'Brand_Sales_10', 'Brand_Sales_11']
# ['Brand_Sales_12', 'Brand_Sales_13']
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Pre_Average'] = round(test_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1[f'{var_index}_Post_Average'] = round(test_data1[post_columns].sum(axis=1) / len(post_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Pre_Control_Average'] =round(control_data1[pre_columns].sum(axis=1) / len(pre_columns),2)
# c:\Users\LENOVO\Desktop\TnC\TestandControl-Python-develop\TestandControl-Python-develop\apps\tc_python\tc\results_page.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data1[f'{var_index}_Post_Control_Average'] =round(control_data1[post_columns].sum(axis=1) / len(post_columns),2)

# %%
res
# Out:
# {'Speaker_Program': 27.326325078945242, 'Mobile_Alerts': 30.51659942957498}

# %%
avg_table_dict
# Out:
# {'Speaker_Program': {'pre_test_avg': 45.44365,
#   'post_test_avg': 54.5375,
#   'pre_control_avg': 36.3694,
#   'post_control_avg': 34.285},
#  'Mobile_Alerts': {'pre_test_avg': 44.8287,
#   'post_test_avg': 54.51625,
#   'pre_control_avg': 36.382675,
#   'post_control_avg': 33.67875}}
